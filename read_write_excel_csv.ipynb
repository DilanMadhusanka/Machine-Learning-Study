# %%
import pandas as pd
df = pd.read_csv('dataset\\stock_data.csv', skiprows=1)
df
# Out:
#   GOOGL          27.82   87   845     larry page
# 0   WMT           4.61  484    65           n.a.
# 1  MSFT             -1   85    64     bill gates
# 2  RIL   not available   50  1023  mukesh ambani
# 3  TATA            5.6   -1  n.a.     ratan tata

# %% [markdown]
# ## Add a row

# %%
import pandas as pd
df = pd.read_csv('dataset\\stock_data.csv')
df
# Out:
#   stock data     Unnamed: 1 Unnamed: 2 Unnamed: 3     Unnamed: 4
# 0    tickers            eps    revenue      price         people
# 1      GOOGL          27.82         87        845     larry page
# 2        WMT           4.61        484         65           n.a.
# 3       MSFT             -1         85         64     bill gates
# 4       RIL   not available         50       1023  mukesh ambani
# 5       TATA            5.6         -1       n.a.     ratan tata

# %%
import pandas as pd
df = pd.read_csv('dataset\\stock_data.csv', header=1)
df
# Out:
#   tickers            eps  revenue price         people
# 0   GOOGL          27.82       87   845     larry page
# 1     WMT           4.61      484    65           n.a.
# 2    MSFT             -1       85    64     bill gates
# 3    RIL   not available       50  1023  mukesh ambani
# 4    TATA            5.6       -1  n.a.     ratan tata

# %%
from IPython.display import Image
Image("F:\Github\Machine-Learning-Study\img\csv.PNG", width=500, height=400)

# %% [markdown]
# ## Delete Header

# %%
import pandas as pd
df = pd.read_csv('dataset\\stock_data.csv')
df
# Out:
#   GOOGL          27.82   87   845     larry page
# 0   WMT           4.61  484    65           n.a.
# 1  MSFT             -1   85    64     bill gates
# 2  RIL   not available   50  1023  mukesh ambani
# 3  TATA            5.6   -1  n.a.     ratan tata

# %%
import pandas as pd
df = pd.read_csv('dataset\\stock_data.csv', header=None)
df
# Out:
#        0              1    2     3              4
# 0  GOOGL          27.82   87   845     larry page
# 1    WMT           4.61  484    65           n.a.
# 2   MSFT             -1   85    64     bill gates
# 3   RIL   not available   50  1023  mukesh ambani
# 4   TATA            5.6   -1  n.a.     ratan tata

# %%
import pandas as pd
df = pd.read_csv('dataset\\stock_data.csv', header=None, names=["ticker", "eps", "revenue", "price", "people"])
df
# Out:
#   ticker            eps  revenue price         people
# 0  GOOGL          27.82       87   845     larry page
# 1    WMT           4.61      484    65           n.a.
# 2   MSFT             -1       85    64     bill gates
# 3   RIL   not available       50  1023  mukesh ambani
# 4   TATA            5.6       -1  n.a.     ratan tata

# %%
Image("F:\Github\Machine-Learning-Study\img\csv2.PNG", width=500, height=400)

# %% [markdown]
# ## Reset the csv

# %%
Image("F:\Github\Machine-Learning-Study\img\csv3.PNG", width=500, height=400)

# %%
import pandas as pd
df = pd.read_csv('dataset\\stock_data.csv')
df
# Out:
#   tickers            eps  revenue price         people
# 0   GOOGL          27.82       87   845     larry page
# 1     WMT           4.61      484    65           n.a.
# 2    MSFT             -1       85    64     bill gates
# 3    RIL   not available       50  1023  mukesh ambani
# 4    TATA            5.6       -1  n.a.     ratan tata

# %%
import pandas as pd
df = pd.read_csv('dataset\\stock_data.csv', nrows=3)
df
# Out:
#   tickers    eps  revenue  price      people
# 0   GOOGL  27.82       87    845  larry page
# 1     WMT   4.61      484     65        n.a.
# 2    MSFT  -1.00       85     64  bill gates

# %%
import pandas as pd
df = pd.read_csv('dataset\\stock_data.csv', na_values=["not-available", "n.a."])
df
# Out:
#   tickers            eps  revenue   price         people
# 0   GOOGL          27.82       87   845.0     larry page
# 1     WMT           4.61      484    65.0            NaN
# 2    MSFT             -1       85    64.0     bill gates
# 3    RIL   not available       50  1023.0  mukesh ambani
# 4    TATA            5.6       -1     NaN     ratan tata

# %%
import pandas as pd
df = pd.read_csv('dataset\\stock_data.csv', na_values=["not-available", "n.a.", -1])
df
# Out:
#   tickers            eps  revenue   price         people
# 0   GOOGL          27.82     87.0   845.0     larry page
# 1     WMT           4.61    484.0    65.0            NaN
# 2    MSFT            NaN     85.0    64.0     bill gates
# 3    RIL   not available     50.0  1023.0  mukesh ambani
# 4    TATA            5.6      NaN     NaN     ratan tata

# %%
import pandas as pd
df = pd.read_csv('dataset\\stock_data.csv', na_values={
    'eps': ["not available", "n.a."],
    'revenue': ["not-available", "n.a.", -1],
    'people': ["not-available", "n.a."]
})
df
# Out:
#   tickers    eps  revenue price         people
# 0   GOOGL  27.82     87.0   845     larry page
# 1     WMT   4.61    484.0    65            NaN
# 2    MSFT  -1.00     85.0    64     bill gates
# 3    RIL     NaN     50.0  1023  mukesh ambani
# 4    TATA   5.60      NaN  n.a.     ratan tata

# %%
df.to_csv('dataset/new.csv')

# %%
from IPython.display import Image
Image("F:\Github\Machine-Learning-Study\img\csv4.PNG", width=500, height=400)

# %%
df.to_csv('dataset/new.csv', index=False)

# %%
Image("F:\Github\Machine-Learning-Study\img\csv5.PNG", width=500, height=400)

# %%
df.columns
# Out:
# Index(['tickers', 'eps', 'revenue', 'price', 'people'], dtype='object')

# %%
df.to_csv('dataset/new.csv', columns=['tickers', 'eps'])

# %%
Image("F:\Github\Machine-Learning-Study\img\csv6.PNG", width=500, height=400)

# %%
df.to_csv('dataset/new.csv', header=False)

# %%
Image("F:\Github\Machine-Learning-Study\img\csv7.PNG", width=500, height=400)

# %%
df = pd.read_excel("dataset\stock_data.xlsx", "Sheet1")
df
# Out:
#   tickers            eps  revenue price         people
# 0   GOOGL          27.82       87   845     larry page
# 1     WMT           4.61      484    65           n.a.
# 2    MSFT             -1       85    64     bill gates
# 3    RIL   not available       50  1023  mukesh ambani
# 4    TATA            5.6       -1  n.a.     ratan tata

# %%
def convert_people_cell(cell):
    if cell == 'n.a.':
        return 'sam walton'
    return cell

def convert_eps_cell(cell):
    if cell == 'not available':
        return None
    return cell

df = pd.read_excel("dataset\stock_data.xlsx", "Sheet1", converters = {
    'people': convert_people_cell,
    'eps': convert_eps_cell
})

df
# Out:
#   tickers    eps  revenue price         people
# 0   GOOGL  27.82       87   845     larry page
# 1     WMT   4.61      484    65     sam walton
# 2    MSFT  -1.00       85    64     bill gates
# 3    RIL     NaN       50  1023  mukesh ambani
# 4    TATA   5.60       -1  n.a.     ratan tata

# %%
df.to_excel("dataset/new.xlsx", sheet_name="stocks")

# %%
Image("F:\Github\Machine-Learning-Study\img\csv8.PNG", width=500, height=400)

# %%
df.to_excel("dataset/new.xlsx", sheet_name="stocks", startrow=1, startcol=2)

# %%
Image("F:\Github\Machine-Learning-Study\img\csv9.PNG", width=500, height=400)

# %%
df.to_excel("dataset/new.xlsx", sheet_name="stocks", startrow=1, startcol=2, index=False)

# %%
Image("F:\Github\Machine-Learning-Study\img\csv10.PNG", width=500, height=400)

# %% [markdown]
# ## DataFrame

# %%
df_stocks = pd.DataFrame({
    'tickers': ['GOOGL', 'WMT', 'MSFT'],
    'price': [845, 65, 64],
    'pe': [30.37, 14.26, 30.97],
    'eps': [27.82, 4.61, 2.12]
})

df_weather = pd.DataFrame({
    'day': ['1/1/2017', '1/2/2017', '1/3/2017'],
    'temperature': [32, 35, 28],
    'event': ['Rain', 'Sunny', 'Snow']
})

# %%
with pd.ExcelWriter('dataset/stocks_weather.xlsx') as writer:
    df_stocks.to_excel(writer, sheet_name="stocks")
    df_weather.to_excel(writer, sheet_name="weather")

# %%
Image("F:\Github\Machine-Learning-Study\img\csv11.PNG", width=500, height=400)

# %%
Image("F:\Github\Machine-Learning-Study\img\csv12.PNG", width=500, height=400)
